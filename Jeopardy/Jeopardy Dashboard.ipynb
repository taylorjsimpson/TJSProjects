# %%
import csv

# %%
from pandas import DataFrame

# %%
import numpy as np
import pandas as pd

# %%
import glob

# %%
from os import listdir

# %%
import dateutil

# %%
from array import *

# %%
import random

# %%
df1 = pd.read_csv(r"C:\Users\taylo\Desktop\GA\DSI_Assignments_NEW\Jeopardy\jeopardy_clues\season1.tsv", sep="\t")

# %%
df1
# Out:
#       round  value daily_double         category  \
# 0         1    100           no   LAKES & RIVERS
# 1         1    200           no   LAKES & RIVERS
# 2         1    400           no   LAKES & RIVERS
# 3         1    500           no   LAKES & RIVERS
# 4         1    100           no       INVENTIONS
# 5         1    200           no       INVENTIONS
# 6         1    300           no       INVENTIONS
# 7         1    400           no       INVENTIONS
# 8         1    100           no          ANIMALS
# 9         1    200           no          ANIMALS
# 10        1    300           no          ANIMALS
# 11        1    400           no          ANIMALS
# 12        1    500           no          ANIMALS
# 13        1    100           no  FOREIGN CUISINE
# 14        1    200           no  FOREIGN CUISINE
# 15        1    300           no  FOREIGN CUISINE
# 16        1    400           no  FOREIGN CUISINE
# 17        1    100           no   ACTORS & ROLES
# ...

# %%
file_name = r"C:\Users\taylo\Desktop\GA\DSI_Assignments_NEW\Jeopardy\jeopardy_clues\season{}.tsv"
df = pd.DataFrame(columns=['round','value','daily_double','category','comments','answer','question', 'air_data', 'notes'])
for i in range(1, 35):
    temp = pd.read_csv(file_name.format(i), sep = "\t", error_bad_lines = False)
    df = df.append(temp, sort = False)

# %%
df.head()
# Out:
#   round value daily_double        category comments  \
# 0     1   100           no  LAKES & RIVERS        -
# 1     1   200           no  LAKES & RIVERS        -
# 2     1   400           no  LAKES & RIVERS        -
# 3     1   500           no  LAKES & RIVERS        -
# 4     1   100           no      INVENTIONS        -
#
#                                               answer         question  \
# 0            River mentioned most often in the Bible       the Jordan
# 1                             Scottish word for lake             loch
# 2  American river only 33 miles shorter than the ...     the Missouri
# 3  World's largest lake, nearly 5 times as big as...  the Caspian Sea
# 4                       Marconi's wonderful wireless        the radio
#
#   air_data notes    air_date
# 0      NaN     -  1984-09-10
# 1      NaN     -  1984-09-10
# 2      NaN     -  1984-09-10
# 3      NaN     -  1984-09-10
# 4      NaN     -  1984-09-10

# %%
df.tail()
# Out:
#       round value daily_double              category  \
# 12041     2   800           no  FOUND IN TRANSLATION
# 12042     2  1200           no  FOUND IN TRANSLATION
# 12043     2  1600           no  FOUND IN TRANSLATION
# 12044     2  2000           no  FOUND IN TRANSLATION
# 12045     3     0           no      AMERICAN HISTORY
#
#                                                 comments  \
# 12041  (Alex: Each correct response will be a word--a...
# 12042  (Alex: Each correct response will be a word--a...
# 12043  (Alex: Each correct response will be a word--a...
# 12044  (Alex: Each correct response will be a word--a...
# 12045                                                  -
#
#                                                   answer  \
# 12041           A facetious, often bawdy tribute banquet
# 12042  Irregular plural word for multiple layers of s...
# 12043                        To lean or tilt to one side
# 12044  Push the blue button in your GM car to get thi...
# ...

# %%
df.isnull()
# Out:
#        round  value  daily_double  category  comments  answer  question  \
# 0      False  False         False     False     False   False     False
# 1      False  False         False     False     False   False     False
# 2      False  False         False     False     False   False     False
# 3      False  False         False     False     False   False     False
# 4      False  False         False     False     False   False     False
# 5      False  False         False     False     False   False     False
# 6      False  False         False     False     False   False     False
# 7      False  False         False     False     False   False     False
# 8      False  False         False     False     False   False     False
# 9      False  False         False     False     False   False     False
# 10     False  False         False     False     False   False     False
# 11     False  False         False     False     False   False     False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 337567 entries, 0 to 12045
# Data columns (total 10 columns):
# round           337567 non-null object
# value           337567 non-null object
# daily_double    337567 non-null object
# category        337567 non-null object
# comments        337567 non-null object
# answer          337567 non-null object
# question        337567 non-null object
# air_data        0 non-null object
# notes           337567 non-null object
# air_date        337567 non-null object
# dtypes: object(10)
# memory usage: 28.3+ MB

# %%
df.columns
# Out:
# Index(['round', 'value', 'daily_double', 'category', 'comments', 'answer',
#        'question', 'air_data', 'notes', 'air_date'],
#       dtype='object')

# %%
df.category
# Out:
# 0                   LAKES & RIVERS
# 1                   LAKES & RIVERS
# 2                   LAKES & RIVERS
# 3                   LAKES & RIVERS
# 4                       INVENTIONS
# 5                       INVENTIONS
# 6                       INVENTIONS
# 7                       INVENTIONS
# 8                          ANIMALS
# 9                          ANIMALS
# 10                         ANIMALS
# 11                         ANIMALS
# 12                         ANIMALS
# 13                 FOREIGN CUISINE
# 14                 FOREIGN CUISINE
# 15                 FOREIGN CUISINE
# 16                 FOREIGN CUISINE
# 17                  ACTORS & ROLES
# 18                  ACTORS & ROLES
# 19                  ACTORS & ROLES
# 20                  ACTORS & ROLES
# 21                  ACTORS & ROLES
# 22                       THE BIBLE
# 23                       THE BIBLE
# 24                       THE BIBLE
# 25                       THE BIBLE
# 26                       THE BIBLE
# ...

# %%
df
# Out:
#       round value daily_double                   category  \
# 0         1   100           no             LAKES & RIVERS
# 1         1   200           no             LAKES & RIVERS
# 2         1   400           no             LAKES & RIVERS
# 3         1   500           no             LAKES & RIVERS
# 4         1   100           no                 INVENTIONS
# 5         1   200           no                 INVENTIONS
# 6         1   300           no                 INVENTIONS
# 7         1   400           no                 INVENTIONS
# 8         1   100           no                    ANIMALS
# 9         1   200           no                    ANIMALS
# 10        1   300           no                    ANIMALS
# 11        1   400           no                    ANIMALS
# 12        1   500           no                    ANIMALS
# 13        1   100           no            FOREIGN CUISINE
# 14        1   200           no            FOREIGN CUISINE
# ...

# %%
 df['category'].values
# Out:
# array(['LAKES & RIVERS', 'LAKES & RIVERS', 'LAKES & RIVERS', ...,
#        'FOUND IN TRANSLATION', 'FOUND IN TRANSLATION', 'AMERICAN HISTORY'],
#       dtype=object)

# %%
a = df['category'].unique()
a.sort()
print(a)
# Out:
# [' A JIM CARREY FILM FESTIVAL' '#1 HITS' '#1 SONGS' ... '“SOUTH”'
#  '“STREETS”' '“WH”AT IS IT?']

# %%
 df['category'].value_counts()
# Out:
# SCIENCE                                        842
# LITERATURE                                     794
# AMERICAN HISTORY                               757
# HISTORY                                        701
# SPORTS                                         700
# POTPOURRI                                      679
# BEFORE & AFTER                                 656
# WORD ORIGINS                                   655
# WORLD HISTORY                                  635
# WORLD GEOGRAPHY                                625
# BUSINESS & INDUSTRY                            591
# U.S. CITIES                                    565
# TRANSPORTATION                                 549
# RELIGION                                       540
# COLLEGES & UNIVERSITIES                        539
# ART                                            524
# WORLD CAPITALS                                 508
# ANIMALS                                        503
# ...

# %%
 df['category'].value_counts().nlargest(20)
# Out:
# SCIENCE                    842
# LITERATURE                 794
# AMERICAN HISTORY           757
# HISTORY                    701
# SPORTS                     700
# POTPOURRI                  679
# BEFORE & AFTER             656
# WORD ORIGINS               655
# WORLD HISTORY              635
# WORLD GEOGRAPHY            625
# BUSINESS & INDUSTRY        591
# U.S. CITIES                565
# TRANSPORTATION             549
# RELIGION                   540
# COLLEGES & UNIVERSITIES    539
# ART                        524
# WORLD CAPITALS             508
# ANIMALS                    503
# U.S. HISTORY               495
# U.S. GEOGRAPHY             493
# Name: category, dtype: int64

# %%
largest20 =  df['category'].value_counts().nlargest(20)

# %%
largest20.describe
# Out:
# <bound method NDFrame.describe of SCIENCE                    842
# LITERATURE                 794
# AMERICAN HISTORY           757
# HISTORY                    701
# SPORTS                     700
# POTPOURRI                  679
# BEFORE & AFTER             656
# WORD ORIGINS               655
# WORLD HISTORY              635
# WORLD GEOGRAPHY            625
# BUSINESS & INDUSTRY        591
# U.S. CITIES                565
# TRANSPORTATION             549
# RELIGION                   540
# COLLEGES & UNIVERSITIES    539
# ART                        524
# WORLD CAPITALS             508
# ANIMALS                    503
# U.S. HISTORY               495
# U.S. GEOGRAPHY             493
# Name: category, dtype: int64>

# %%
largest20
# Out:
# SCIENCE                    842
# LITERATURE                 794
# AMERICAN HISTORY           757
# HISTORY                    701
# SPORTS                     700
# POTPOURRI                  679
# BEFORE & AFTER             656
# WORD ORIGINS               655
# WORLD HISTORY              635
# WORLD GEOGRAPHY            625
# BUSINESS & INDUSTRY        591
# U.S. CITIES                565
# TRANSPORTATION             549
# RELIGION                   540
# COLLEGES & UNIVERSITIES    539
# ART                        524
# WORLD CAPITALS             508
# ANIMALS                    503
# U.S. HISTORY               495
# U.S. GEOGRAPHY             493
# Name: category, dtype: int64

# %%
df20 = pd.DataFrame(largest20)
df20
# Out:
#                          category
# SCIENCE                       842
# LITERATURE                    794
# AMERICAN HISTORY              757
# HISTORY                       701
# SPORTS                        700
# POTPOURRI                     679
# BEFORE & AFTER                656
# WORD ORIGINS                  655
# WORLD HISTORY                 635
# WORLD GEOGRAPHY               625
# BUSINESS & INDUSTRY           591
# U.S. CITIES                   565
# TRANSPORTATION                549
# RELIGION                      540
# COLLEGES & UNIVERSITIES       539
# ART                           524
# WORLD CAPITALS                508
# ANIMALS                       503
# U.S. HISTORY                  495
# U.S. GEOGRAPHY                493

# %%
category_list = df20.index.tolist()
category_list
# Out:
# ['SCIENCE',
#  'LITERATURE',
#  'AMERICAN HISTORY',
#  'HISTORY',
#  'SPORTS',
#  'POTPOURRI',
#  'BEFORE & AFTER',
#  'WORD ORIGINS',
#  'WORLD HISTORY',
#  'WORLD GEOGRAPHY',
#  'BUSINESS & INDUSTRY',
#  'U.S. CITIES',
#  'TRANSPORTATION',
#  'RELIGION',
#  'COLLEGES & UNIVERSITIES',
#  'ART',
#  'WORLD CAPITALS',
#  'ANIMALS',
#  'U.S. HISTORY',
#  'U.S. GEOGRAPHY']

# %%
for category in category_list:
    print(category)
# Out:
# SCIENCE
# LITERATURE
# AMERICAN HISTORY
# HISTORY
# SPORTS
# POTPOURRI
# BEFORE & AFTER
# WORD ORIGINS
# WORLD HISTORY
# WORLD GEOGRAPHY
# BUSINESS & INDUSTRY
# U.S. CITIES
# TRANSPORTATION
# RELIGION
# COLLEGES & UNIVERSITIES
# ART
# WORLD CAPITALS
# ANIMALS
# U.S. HISTORY
# U.S. GEOGRAPHY

# %%
#for category in category list
#search for that category in df1
#create new dataframe from df1 that contains name of category
#continue to create new for every category in category list

# %%
df.head()
# Out:
#   round value daily_double        category comments  \
# 0     1   100           no  LAKES & RIVERS        -
# 1     1   200           no  LAKES & RIVERS        -
# 2     1   400           no  LAKES & RIVERS        -
# 3     1   500           no  LAKES & RIVERS        -
# 4     1   100           no      INVENTIONS        -
#
#                                               answer         question  \
# 0            River mentioned most often in the Bible       the Jordan
# 1                             Scottish word for lake             loch
# 2  American river only 33 miles shorter than the ...     the Missouri
# 3  World's largest lake, nearly 5 times as big as...  the Caspian Sea
# 4                       Marconi's wonderful wireless        the radio
#
#   air_data notes    air_date
# 0      NaN     -  1984-09-10
# 1      NaN     -  1984-09-10
# 2      NaN     -  1984-09-10
# 3      NaN     -  1984-09-10
# 4      NaN     -  1984-09-10

# %%
df1 = df[['category', 'question', 'answer']]
df1
# Out:
#                         category  \
# 0                 LAKES & RIVERS
# 1                 LAKES & RIVERS
# 2                 LAKES & RIVERS
# 3                 LAKES & RIVERS
# 4                     INVENTIONS
# 5                     INVENTIONS
# 6                     INVENTIONS
# 7                     INVENTIONS
# 8                        ANIMALS
# 9                        ANIMALS
# 10                       ANIMALS
# 11                       ANIMALS
# 12                       ANIMALS
# 13               FOREIGN CUISINE
# 14               FOREIGN CUISINE
# 15               FOREIGN CUISINE
# 16               FOREIGN CUISINE
# 17                ACTORS & ROLES
# 18                ACTORS & ROLES
# 19                ACTORS & ROLES
# 20                ACTORS & ROLES
# 21                ACTORS & ROLES
# 22                     THE BIBLE
# 23                     THE BIBLE
# 24                     THE BIBLE
# 25                     THE BIBLE
# 26                     THE BIBLE
# ...

# %%
uniquecategories = df1.category.unique()

# %%
categorydict = {elem : pd.DataFrame() for elem in uniquecategories}

# %%
categorydict
# Out:
# {'LAKES & RIVERS': Empty DataFrame
#  Columns: []
#  Index: [], 'INVENTIONS': Empty DataFrame
#  Columns: []
#  Index: [], 'ANIMALS': Empty DataFrame
#  Columns: []
#  Index: [], 'FOREIGN CUISINE': Empty DataFrame
#  Columns: []
#  Index: [], 'ACTORS & ROLES': Empty DataFrame
#  Columns: []
#  Index: [], 'THE BIBLE': Empty DataFrame
#  Columns: []
#  Index: [], "\\'50'S TV": Empty DataFrame
#  Columns: []
#  Index: [], 'NATIONAL LANDMARKS': Empty DataFrame
#  Columns: []
#  Index: [], 'NOTORIOUS': Empty DataFrame
#  Columns: []
#  Index: [], '4-LETTER WORDS': Empty DataFrame
#  Columns: []
#  Index: [], 'HOLIDAYS': Empty DataFrame
#  Columns: []
#  Index: [], 'STATE CAPITALS': Empty DataFrame
#  Columns: []
#  Index: [], "THE '40'S": Empty DataFrame
#  Columns: []
#  Index: [], 'TRANSPORTATION': Empty DataFrame
#  Columns: []
#  Index: [], 'COUNTRY MUSIC': Empty DataFrame
#  Columns: []
#  Index: [], 'BY THE NUMBERS': Empty DataFrame
#  Columns: []
# ...

# %%
df[:][df1.category == category]
# Out:
#       round value daily_double        category comments  \
# 757       1   100           no  U.S. GEOGRAPHY        -
# 758       1   200           no  U.S. GEOGRAPHY        -
# 759       1   500           no  U.S. GEOGRAPHY        -
# 924       2   200           no  U.S. GEOGRAPHY        -
# 925       2   400           no  U.S. GEOGRAPHY        -
# 926       2   700          yes  U.S. GEOGRAPHY        -
# 927       2   800           no  U.S. GEOGRAPHY        -
# 928       2  1000           no  U.S. GEOGRAPHY        -
# 1383      3     0           no  U.S. GEOGRAPHY        -
# 1609      3     0           no  U.S. GEOGRAPHY        -
# 1756      1   100           no  U.S. GEOGRAPHY        -
# 1757      1   200           no  U.S. GEOGRAPHY        -
# 1758      1   300           no  U.S. GEOGRAPHY        -
# 1759      1   400           no  U.S. GEOGRAPHY        -
# 1760      1   500           no  U.S. GEOGRAPHY        -
# 2364      3     0           no  U.S. GEOGRAPHY        -
# ...

# %%
for category in categorydict.keys():
    categorydict[category] = df[:][df1.category == category]

# %%
categorydict['SCIENCE']
# Out:
#       round value daily_double category comments  \
# 304       3     0           no  SCIENCE        -
# 1017      2   200           no  SCIENCE        -
# 1018      2   400           no  SCIENCE        -
# 1019      2   600           no  SCIENCE        -
# 1020      2   800           no  SCIENCE        -
# 1021      2  1000           no  SCIENCE        -
# 1037      1   100           no  SCIENCE        -
# 1038      1   200           no  SCIENCE        -
# 1039      1   300           no  SCIENCE        -
# 1040      1   400           no  SCIENCE        -
# 1041      1   500           no  SCIENCE        -
# 1338      1   100           no  SCIENCE        -
# 1339      1   200           no  SCIENCE        -
# 1340      1   300           no  SCIENCE        -
# 1341      1   400           no  SCIENCE        -
# 1342      1   500           no  SCIENCE        -
# 1413      2   200           no  SCIENCE        -
# 1414      2   400           no  SCIENCE        -
# ...

# %%
categorydict['HOMONYMS']
# Out:
#      round value daily_double  category  \
# 346      2   200           no  HOMONYMS
# 347      2   400           no  HOMONYMS
# 348      2   600           no  HOMONYMS
# 349      2  1000          yes  HOMONYMS
# 350      2  1000           no  HOMONYMS
# 395      2   200           no  HOMONYMS
# 396      2   400           no  HOMONYMS
# 397      2   600           no  HOMONYMS
# 398      2   800           no  HOMONYMS
# 399      2  1000           no  HOMONYMS
# 1685     2   200           no  HOMONYMS
# 1686     2   400           no  HOMONYMS
# 1687     2   600           no  HOMONYMS
# 6120     1   100           no  HOMONYMS
# 6121     1   200           no  HOMONYMS
# 6122     1   300           no  HOMONYMS
# 6123     1   400           no  HOMONYMS
# 6124     1   500          yes  HOMONYMS
# 8506     2   200           no  HOMONYMS
# 8507     2   400           no  HOMONYMS
# 8508     2   600           no  HOMONYMS
# 8509     2  1000          yes  HOMONYMS
# ...

# %%
categorydict['NORSE GODS'].info
# Out:
# <bound method DataFrame.info of       round value daily_double    category comments  \
# 12036     2   400           no  NORSE GODS        -
# 12037     2   800           no  NORSE GODS        -
# 12038     2  1200           no  NORSE GODS        -
# 12039     2  1600           no  NORSE GODS        -
#
#                                                   answer  \
# 12036  We can thank Freya, the goddess of love, for t...
# 12037  Hermod, whose name means "war spirit", perform...
# 12038  Known for his eloquence & knowledge, Bragi was...
# 12039  Delling, whose name means "luminous one", was ...
#
#                                  question air_data notes    air_date
# 12036                              Friday      NaN     -  2018-07-27
# 12037  delivering messages (or messenger)      NaN     -  2018-07-27
# 12038                               poems      NaN     -  2018-07-27
# 12039                             sunrise      NaN     -  2018-07-27  >

# %%
uniquecategories
# Out:
# array(['LAKES & RIVERS', 'INVENTIONS', 'ANIMALS', ...,
#        'CLASSICAL MUSIC TERMS', 'DEFUNCT SPORTS FRANCHISES', 'NORSE GODS'],
#       dtype=object)

# %%
print(random.choice(uniquecategories))
# Out:
# AMERICA THE BEAUTIFUL

# %%
categorydict['AMERICA THE BEAUTIFUL']
# Out:
#       round value daily_double               category                comments  \
# 7748      2   200           no  AMERICA THE BEAUTIFUL                       -
# 7749      2   400           no  AMERICA THE BEAUTIFUL                       -
# 7750      2   600           no  AMERICA THE BEAUTIFUL                       -
# 7751      2   800           no  AMERICA THE BEAUTIFUL                       -
# 7752      2  1000           no  AMERICA THE BEAUTIFUL                       -
# 11644     1   200           no  AMERICA THE BEAUTIFUL  (Alex: Yes, the song.)
# 11645     1   400           no  AMERICA THE BEAUTIFUL  (Alex: Yes, the song.)
# 11646     1   600           no  AMERICA THE BEAUTIFUL  (Alex: Yes, the song.)
# 11647     1   800           no  AMERICA THE BEAUTIFUL  (Alex: Yes, the song.)
# 11648     1  1000           no  AMERICA THE BEAUTIFUL  (Alex: Yes, the song.)
#
#                                                   answer           question  \
# ...

# %%
#Quiz
#print answers from column in dataframe
#enter your own questions
#if questions entered = questions in df
#print TRUE/FALSE

# %%
print(categorydict['AMERICA THE BEAUTIFUL'].answer.values)
# Out:
# ['The Klamath River rises in this state then empties into the Pacific Ocean in California'
#  "Both Dakotas have areas of eroded terrain called this; South Dakota's has a national park named for it"
#  'The 288-year-old town of Easton, Maryland sits on the eastern shore of this bay'
#  'The last time both major party conventions were held in the same place was 1972 in this southern "beach" city'
#  'The "files" on this large Illinois city include its historic leadership in screw production'
#  '\\"America!  America!  God shed his Grace on thee/ And crown thy good with brotherhood  from sea to" this'
#  '\\"O beautiful for spacious skies, for amber waves of grain/ For purple mountain majesties, above"  these 3 words'
#  '\\"O beautiful for patriot dream, that sees beyond the years/ Thine alabaster cities gleam, undimmed by human" these'
#  '\\"America!  America!  God mend thine every flaw/ Confirm thy soul in self-control, thy liberty in" this'
# ...

# %%
categorydict['AMERICA THE BEAUTIFUL'].answer.values
# Out:
# array(['The Klamath River rises in this state then empties into the Pacific Ocean in California',
#        "Both Dakotas have areas of eroded terrain called this; South Dakota's has a national park named for it",
#        'The 288-year-old town of Easton, Maryland sits on the eastern shore of this bay',
#        'The last time both major party conventions were held in the same place was 1972 in this southern "beach" city',
#        'The "files" on this large Illinois city include its historic leadership in screw production',
#        '\\"America!  America!  God shed his Grace on thee/ And crown thy good with brotherhood  from sea to" this',
#        '\\"O beautiful for spacious skies, for amber waves of grain/ For purple mountain majesties, above"  these 3 words',
#        '\\"O beautiful for patriot dream, that sees beyond the years/ Thine alabaster cities gleam, undimmed by human" these',
# ...

# %%
categorydict['AMERICA THE BEAUTIFUL'].question.values
# Out:
# array(['Oregon', 'Badlands', 'Chesapeake Bay', 'Miami', 'Rockford',
#        'shining sea', 'the fruited plain', 'tears', 'law', 'divine'],
#       dtype=object)

# %%
from random import sample

# %%
rofa = categorydict['AMERICA THE BEAUTIFUL'].answer.values
rofa
# Out:
# array(['The Klamath River rises in this state then empties into the Pacific Ocean in California',
#        "Both Dakotas have areas of eroded terrain called this; South Dakota's has a national park named for it",
#        'The 288-year-old town of Easton, Maryland sits on the eastern shore of this bay',
#        'The last time both major party conventions were held in the same place was 1972 in this southern "beach" city',
#        'The "files" on this large Illinois city include its historic leadership in screw production',
#        '\\"America!  America!  God shed his Grace on thee/ And crown thy good with brotherhood  from sea to" this',
#        '\\"O beautiful for spacious skies, for amber waves of grain/ For purple mountain majesties, above"  these 3 words',
#        '\\"O beautiful for patriot dream, that sees beyond the years/ Thine alabaster cities gleam, undimmed by human" these',
# ...

# %%
rofaL = rofa.tolist()
rofaL
# Out:
# ['The Klamath River rises in this state then empties into the Pacific Ocean in California',
#  "Both Dakotas have areas of eroded terrain called this; South Dakota's has a national park named for it",
#  'The 288-year-old town of Easton, Maryland sits on the eastern shore of this bay',
#  'The last time both major party conventions were held in the same place was 1972 in this southern "beach" city',
#  'The "files" on this large Illinois city include its historic leadership in screw production',
#  '\\"America!  America!  God shed his Grace on thee/ And crown thy good with brotherhood  from sea to" this',
#  '\\"O beautiful for spacious skies, for amber waves of grain/ For purple mountain majesties, above"  these 3 words',
#  '\\"O beautiful for patriot dream, that sees beyond the years/ Thine alabaster cities gleam, undimmed by human" these',
#  '\\"America!  America!  God mend thine every flaw/ Confirm thy soul in self-control, thy liberty in" this',
# ...

# %%
rofq = categorydict['AMERICA THE BEAUTIFUL'].question.values
rofq
# Out:
# array(['Oregon', 'Badlands', 'Chesapeake Bay', 'Miami', 'Rockford',
#        'shining sea', 'the fruited plain', 'tears', 'law', 'divine'],
#       dtype=object)

# %%
rofqL = rofq.tolist()
rofqL

# %%
from random import sample

Questions = rofaL
             

Answers = rofqL
           

num_right = 0

# Personal taste, I prefer the zipped list of Q & A rather than an index lookup in the for loop
# Ex: key[0] == ('What is the capital of the United States of America? ', 'Washington DC')
# Final note, the zip function returns a generator, so we need to transform it to a list object for sample()
key = list(zip(Questions, Answers))

# Sample from key now instead of Questions
s = sample(key, 5)

for i in s:
    # in each "i" tuple [0] is the question, [1] is the answer
    print(i[0])
    user_answer = input('Your Guess: ')
    if user_answer.lower() == i[1].lower():
        print('Correct!!!')
        num_right += 1
    else:
        print('Not Correct')
# Added a final fraction of correct statement
print('{}/5 Questions Correct'.format(num_right))
